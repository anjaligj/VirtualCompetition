# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('train_v9rqX0R.csv')

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#Dropping item weight as it might not contribute to the sales
data1=data.drop('Item_Weight',axis=1)

# %%
data1.Outlet_Size.nunique()
# Out:
# 3

# %%
data1.Outlet_Size.unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
#dropping Outlet Size
data2=data1.drop('Outlet_Size',axis=1)

# %%
#Eliminating columns which may notcontribute to the model
data3=data2.drop(['Item_Identifier'],axis=1)

# %%
data3
# Out:
#      Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 0             Low Fat         0.016047                  Dairy  249.8092
# 1             Regular         0.019278            Soft Drinks   48.2692
# 2             Low Fat         0.016760                   Meat  141.6180
# 3             Regular         0.000000  Fruits and Vegetables  182.0950
# 4             Low Fat         0.000000              Household   53.8614
# ...               ...              ...                    ...       ...
# 8518          Low Fat         0.056783            Snack Foods  214.5218
# 8519          Regular         0.046982           Baking Goods  108.1570
# 8520          Low Fat         0.035186     Health and Hygiene   85.1224
# 8521          Regular         0.145221            Snack Foods  103.1332
# 8522          Low Fat         0.044878            Soft Drinks   75.4670
#
#      Outlet_Identifier  Outlet_Establishment_Year Outlet_Location_Type  \
# ...

# %%
data3.Item_Type.unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
#Doing label encoding 
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()

# %%
data3['Item_Type']=lb.fit_transform(data3['Item_Type'])

# %%
data3.Outlet_Identifier.unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
lb2=preprocessing.LabelEncoder()
data3['Outlet_Identifier']=lb2.fit_transform(data3['Outlet_Identifier'])

# %%
data3.Outlet_Type.unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
lb3=preprocessing.LabelEncoder()
data3['Outlet_Type']=lb3.fit_transform(data3['Outlet_Type'])

# %%
data3.Outlet_Location_Type.unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
data3
# Out:
#      Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0             Low Fat         0.016047          4  249.8092
# 1             Regular         0.019278         14   48.2692
# 2             Low Fat         0.016760         10  141.6180
# 3             Regular         0.000000          6  182.0950
# 4             Low Fat         0.000000          9   53.8614
# ...               ...              ...        ...       ...
# 8518          Low Fat         0.056783         13  214.5218
# 8519          Regular         0.046982          0  108.1570
# 8520          Low Fat         0.035186          8   85.1224
# 8521          Regular         0.145221         13  103.1332
# 8522          Low Fat         0.044878         14   75.4670
#
#       Outlet_Identifier  Outlet_Establishment_Year Outlet_Location_Type  \
# 0                     9                       1999               Tier 1
# 1                     3                       2009               Tier 3
# ...

# %%
data3.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
lb4=preprocessing.LabelEncoder()
data3['Item_Fat_Content']=lb4.fit_transform(data3['Item_Fat_Content'])

# %%
data['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
data3=pd.get_dummies(data3)

# %%
data3
# Out:
#       Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0                    1         0.016047          4  249.8092
# 1                    2         0.019278         14   48.2692
# 2                    1         0.016760         10  141.6180
# 3                    2         0.000000          6  182.0950
# 4                    1         0.000000          9   53.8614
# ...                ...              ...        ...       ...
# 8518                 1         0.056783         13  214.5218
# 8519                 2         0.046982          0  108.1570
# 8520                 1         0.035186          8   85.1224
# 8521                 2         0.145221         13  103.1332
# 8522                 1         0.044878         14   75.4670
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Type  \
# 0                     9                       1999            1
# 1                     3                       2009            2
# ...

# %%
#x and y split
x=data3.drop('Item_Outlet_Sales',axis=1)
y=data3['Item_Outlet_Sales']

# %%
#performing train test
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
l=LinearRegression()

# %%
model=l.fit(x_train,y_train)

# %%
//y_test=data3['Item_Outlet_Sales']
//y_test=y_test.iloc[:5681]

# %%
y_test.shape
# Out:
# (5681,)

# %%
#Loading test data
data_test=pd.read_csv('test_AbJTz2l.csv')

# %%
data_test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
data_test.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
data_test1=data_test.drop(['Item_Weight','Outlet_Size','Item_Identifier'],axis=1)

# %%
data_test1.head()
# Out:
#   Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP Outlet_Identifier  \
# 0          Low Fat         0.007565  Snack Foods  107.8622            OUT049
# 1              reg         0.038428        Dairy   87.3198            OUT017
# 2          Low Fat         0.099575       Others  241.7538            OUT010
# 3          Low Fat         0.015388  Snack Foods  155.0340            OUT017
# 4          Regular         0.118599        Dairy  234.2300            OUT027
#
#    Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type
# 0                       1999               Tier 1  Supermarket Type1
# 1                       2007               Tier 2  Supermarket Type1
# 2                       1998               Tier 3      Grocery Store
# 3                       2007               Tier 2  Supermarket Type1
# 4                       1985               Tier 3  Supermarket Type3

# %%
lb5=preprocessing.LabelEncoder()
data_test1['Outlet_Type']=lb5.fit_transform(data_test1['Outlet_Type'])

# %%
lb6=preprocessing.LabelEncoder()
data_test1['Item_Fat_Content']=lb6.fit_transform(data_test1['Item_Fat_Content'])

# %%
lb7=preprocessing.LabelEncoder()
data_test1['Item_Type']=lb7.fit_transform(data_test1['Item_Type'])

# %%
lb8=preprocessing.LabelEncoder()
data_test1['Outlet_Identifier']=lb8.fit_transform(data_test1['Outlet_Identifier'])

# %%
data_test1.shape
# Out:
# (5681, 8)

# %%
data_test['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 2', 'Tier 3'], dtype=object)

# %%
data_test1=pd.get_dummies(data_test1)

# %%
data_test1.shape
# Out:
# (5681, 10)

# %%
data_test1
# Out:
#       Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0                    1         0.007565         13  107.8622
# 1                    4         0.038428          4   87.3198
# 2                    1         0.099575         11  241.7538
# 3                    1         0.015388         13  155.0340
# 4                    2         0.118599          4  234.2300
# ...                ...              ...        ...       ...
# 5676                 2         0.013496         13  141.3154
# 5677                 2         0.142991         15  169.1448
# 5678                 1         0.073529          8  118.7440
# 5679                 2         0.000000          3  214.6218
# 5680                 2         0.104720          3   79.7960
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Type  \
# 0                     9                       1999            1
# 1                     2                       2007            1
# ...

# %%
prediction=model.predict(data_test1)

# %%
prediction.shape
# Out:
# (5681,)

# %%
y_test.shape
# Out:
# (5681,)

# %%
#creating evaluation matrix for comparing actual y test and predicted value
from sklearn.metrics import mean_squared_error,r2_score
print("Mean squared error is",mean_squared_error(y_test,prediction))
print("R square value is",r2_score(y_test,prediction))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-effb05c44146> in <module>
#       1 #creating evaluation matrix for comparing actual y test and predicted value
#       2 from sklearn.metrics import mean_squared_error,r2_score
# ----> 3 print("Mean squared error is",mean_squared_error(y_test,prediction))
#       4 print("R square value is",r2_score(y_test,prediction))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     437     """
#     438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 439         y_true, y_pred, multioutput
#     440     )
#     441     check_consistent_length(y_true, y_pred, sample_weight)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
# ...

# %%
prediction.dtype
# Out:
# dtype('float64')

# %%
submission=pd.read_csv('sample_submission_8RXa3c6.csv')

# %%
submission
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049               1000
# 1              FDW14            OUT017               1000
# 2              NCN55            OUT010               1000
# 3              FDQ58            OUT017               1000
# 4              FDY38            OUT027               1000
# ...              ...               ...                ...
# 5676           FDB58            OUT046               1000
# 5677           FDD47            OUT018               1000
# 5678           NCO17            OUT045               1000
# 5679           FDJ26            OUT017               1000
# 5680           FDU37            OUT045               1000
#
# [5681 rows x 3 columns]

# %%
submission['Item_Outlet_Sales']=prediction

# %%
submission
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049        1614.064572
# 1              FDW14            OUT017        1440.212096
# 2              NCN55            OUT010        2073.177545
# 3              FDQ58            OUT017        2409.427646
# 4              FDY38            OUT027        5237.160619
# ...              ...               ...                ...
# 5676           FDB58            OUT046        2174.421293
# 5677           FDD47            OUT018        2600.185245
# 5678           NCO17            OUT045        2081.882449
# 5679           FDJ26            OUT017        3413.673638
# 5680           FDU37            OUT045        1464.737291
#
# [5681 rows x 3 columns]

# %%
submission.to_csv(r'C:\Users\virtual_com2.csv')
